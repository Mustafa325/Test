# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio
#
# **Mostafa Abualsaud** Petorleum Engineer
#
# *I am interested in data science because I would like to change industries or pick a skill that might help me if I decide otherwise.*
#
# ### The following code tests the Power of a Number Formula

# %%
2**2
# Out:
# 4

# %% [markdown]
# ***
#
# Testing my Jupyter Notebook skills
#
# ***
#
# <a href="https://www.ibm.com/cloud/watson-studio" target="_blank">IBM Watson Studio</a>
#
# 1. one
# 2. two
# 3. three
#
# * First
# * Second
# * Third
#
# | First Name | Last Name |
# | --- | --- |
# | Mostafa | Abualsaud |
#
# ~Strikethrough~
#
# ![BOY%20#1.webp](attachment:BOY%20#1.webp)
#
# `End of Test`
