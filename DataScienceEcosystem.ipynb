# %% [markdown]
# ## Auther
# Mostafa Abualsaud

# %% [markdown]
# # Data Science Tools and Ecosystem
#
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
#
#     * List popular languages for Data Science
#     * Commonly used libraries used by Data Scientists
#     * Data Science Tools

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Java
# 6. C++
#
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. Python Libraries:
#     * Pandas
#     * NumPy
#     * matplotlib
# 2. Scikit-learn
# 3. Keras
# 4. TensorFlow
# 5. Spark
# 6. ggplot2
#
# | Data Science Tools |||
# | -------- | --------- | --------- |
# | Open Source Tools | Commercial Tools | Cloud Base Tools |
# | --------- | --------- | --------- |
# |Jupyter | Watson Studio Desktop| Watson Studio |
# |MySQL |Microsoft SQL Server | Microsoft Azure Machine Learning|
# |RStudio | IBM Db2| H2O Driverless AI |
# |Apache Spark |Oracle Database |  Amazon Web Services DynamoDB |
#
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
a =(3*4)+5 
print(f"This a simple arithmetic expression to mutiply then add integers: {a}")
# Out:
# This a simple arithmetic expression to mutiply then add integers: 17

# %%
min = int(input("Enter time in minutes: "))

hr = min/60

print(f"Time in hours: {hr}")
# Out:
# Enter time in minutes: 200
# Time in hours: 3.3333333333333335
